# %%
import re

import nltk

# %%
# download punk package if it's absent
nltk.download("punkt")
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/titart/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/titart/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Build dataset from plain text

# %%
def check_str(s):
    return s.isspace() is not True and s is not ""

# %%
"abc ..\n"[-4:-1]
# Out:
# ' ..'

# %%
STOP_WORDS = [u"—", u":", u"«", u"»", u"[", u"]"]
PUNCTS = [u".", u",", u"?", u"!"]

def convert_line_to_sents(line, line_proc):
    sents = nltk.tokenize.sent_tokenize(line)
    
    ext_sents = []
    for sent in sents:
        # splits sentences by ";" to increase total amount of lines
        ts = sent.split(";")
        ext_sents.extend(filter(None, ts))

    res = []
    for s in ext_sents:
        words = [w.lower() for w in nltk.tokenize.word_tokenize(s) if w not in STOP_WORDS]
        
        # take lines contains up 1 to 17 words
        if 1 < len(words) < 20:
            
            # skip lines contains only word and punctuation mark like "someword ."
            if len(words) == 2 and words[1] in PUNCTS:
                continue
            
            line = " ".join(words) + "\n"
            line = re.sub(r"\b\d+\b", "_num_", line)
            
            line = line_proc(line)
            
            res.append(line)
    
    return res

# %%
def text2sents(source, target, line_proc=lambda s: s):
    target_file = open(target, "w")
    with open(source, "r") as source_file:
        for line in source_file:
            line = line.decode("utf-8")
            sents = convert_line_to_sents(line, line_proc)
            if not sents:
                continue

            target_file.writelines([s.encode("utf-8") for s in sents])

    target_file.close()

# %% [markdown]
# ## Convert file with text of tales to file with sentences

# %%
SOURCE_TALES = "data/tales/tales-text-full.txt"
TARGET_TALES = "data/tales/tales-sents-full.txt"

text2sents(SOURCE_TALES, TARGET_TALES)

# %% [markdown]
# ## Convert file with text of news to file with sentences

# %%
SOURCE_NEWS = "data/news/meduza-news.txt"
TARGET_NEWS = "data/news/news-sents.txt"

text2sents(SOURCE_NEWS, TARGET_NEWS)

# %%
SOURCE_DOSTOEVSKY = "data/dostoevsky/dostoevsky-all.txt"
TARGET_DOSTOEVSKY = "data/dostoevsky/dostoevsky-sents.txt"

def dots_processing(line):
    # it resolves problems with three dots in Dostoevsy texts 
    line = line.replace(u"…", "")
    if u" ..\n" in line:
        line = line[:-4] + "\n" 
    
    return line


text2sents(SOURCE_DOSTOEVSKY, TARGET_DOSTOEVSKY, line_proc=dots_processing)

# %%
SOURCE_MARININA = "data/marinina/marinina-all.txt"
TARGET_MARININA = "data/marinina/marinina-sents.txt"

def hyphen_processor(s):
    if u"–" in s:
        s = s.replace(u"– ", "")
        
    return dots_processing(s)

text2sents(SOURCE_MARININA, TARGET_MARININA, hyphen_processor)

# %% [markdown]
# # Parse news corpus from <a href="http://meduza.io">Meduza</a> API

# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
API_PATH = "https://meduza.io/api/v3"

def get_collection(topic="news", locale="ru", page=0, page_size=100):
    params = {"chrono": topic, "locale": locale, "page": page, "per_page": page_size}
    req = requests.get(API_PATH + "/search", params)
    return json.loads(req.content)["collection"]

def get_content(post_path):
    h2t = html2text.HTML2Text()
    req = requests.get(API_PATH + "/" + post_path)
    body = json.loads(req.content)["root"]["content"]["body"]
    soup = BeautifulSoup(body)
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

# %%
NEWS_DATA_FILE = "meduza-news.txt"
PAGES = 40

# WARNING: it takes a lot of time!!!

it = 0
with open(NEWS_DATA_FILE, "w") as f:
    for page in range(PAGES):
        collection = get_collection(page=page)
        for path in collection:
            try:
                f.write(get_content(path).encode("utf-8"))
            except:
                continue
            it += 1
            if it % 5 == 0:
                print "%d lines have been read" % it
# Out:
# 5 lines have been read
# 10 lines have been read
# 15 lines have been read
# 20 lines have been read
# 25 lines have been read
# 30 lines have been read
# 35 lines have been read
# 40 lines have been read
# 45 lines have been read
# 50 lines have been read
# 55 lines have been read
# 60 lines have been read
# 65 lines have been read
# 70 lines have been read
# 75 lines have been read
# 80 lines have been read
# 85 lines have been read
# 90 lines have been read
# 95 lines have been read
# 100 lines have been read
# 105 lines have been read
# 110 lines have been read
# 115 lines have been read
# 120 lines have been read
# 125 lines have been read
# 130 lines have been read
# 135 lines have been read
# 140 lines have been read
# 145 lines have been read
# 150 lines have been read
# 155 lines have been read
# 160 lines have been read
# 165 lines have been read
# 170 lines have been read
# 175 lines have been read
# 180 lines have been read
# 185 lines have been read
# 190 lines have been read
# 195 lines have been read
# 200 lines have been read
# 205 lines have been read
# 210 lines have been read
# 215 lines have been read
# 220 lines have been read
# 225 lines have been read
# 230 lines have been read
# 235 lines have been read
# 240 lines have been read
# 245 lines have been read
# 250 lines have been read
# 255 lines have been read
# 260 lines have been read
# 265 lines have been read
# 270 lines have been read
# 275 lines have been read
# 280 lines have been read
# 285 lines have been read
# 290 lines have been read
# 295 lines have been read
# 300 lines have been read
# 305 lines have been read
# 310 lines have been read
# 315 lines have been read
# 320 lines have been read
# 325 lines have been read
# 330 lines have been read
# 335 lines have been read
# 340 lines have been read
# 345 lines have been read
# 350 lines have been read
# 355 lines have been read
# 360 lines have been read
# 365 lines have been read
# 370 lines have been read
# 375 lines have been read
# 380 lines have been read
# 385 lines have been read
# 390 lines have been read
# 395 lines have been read
# 400 lines have been read
# 405 lines have been read
# 410 lines have been read
# 415 lines have been read
# 420 lines have been read
# 425 lines have been read
# 430 lines have been read
# 435 lines have been read
# 440 lines have been read
# 445 lines have been read
# 450 lines have been read
# 455 lines have been read
# 460 lines have been read
# 465 lines have been read
# 470 lines have been read
# 475 lines have been read
# 480 lines have been read
# 485 lines have been read
# 490 lines have been read
# 495 lines have been read
# 500 lines have been read
# 505 lines have been read
# 510 lines have been read
# 515 lines have been read
# 520 lines have been read
# 525 lines have been read
# 530 lines have been read
# 535 lines have been read
# 540 lines have been read
# 545 lines have been read
# 550 lines have been read
# 555 lines have been read
# 560 lines have been read
# 565 lines have been read
# 570 lines have been read
# 575 lines have been read
# 580 lines have been read
# 585 lines have been read
# 590 lines have been read
# 595 lines have been read
# 600 lines have been read
# 605 lines have been read
# 610 lines have been read
# 615 lines have been read
# 620 lines have been read
# 625 lines have been read
# 630 lines have been read
# 635 lines have been read
# 640 lines have been read
# 645 lines have been read
# 650 lines have been read
# 655 lines have been read
# 660 lines have been read
# 665 lines have been read
# 670 lines have been read
# 675 lines have been read
# 680 lines have been read
# 685 lines have been read
# 690 lines have been read
# 695 lines have been read
# 700 lines have been read
# 705 lines have been read
# 710 lines have been read
# 715 lines have been read
# 720 lines have been read
# 725 lines have been read
# 730 lines have been read
# 735 lines have been read
# 740 lines have been read
# 745 lines have been read
# 750 lines have been read
# 755 lines have been read
# 760 lines have been read
# 765 lines have been read
# 770 lines have been read
# 775 lines have been read
# 780 lines have been read
# 785 lines have been read
# 790 lines have been read
# 795 lines have been read
# 800 lines have been read
# 805 lines have been read
# 810 lines have been read
# 815 lines have been read
# 820 lines have been read
# 825 lines have been read
# 830 lines have been read
# 835 lines have been read
# 840 lines have been read
# 845 lines have been read
# 850 lines have been read
# 855 lines have been read
# 860 lines have been read
# 865 lines have been read
# 870 lines have been read
# 875 lines have been read
# 880 lines have been read
# 885 lines have been read
# 890 lines have been read
# 895 lines have been read
# 900 lines have been read
# 905 lines have been read
# 910 lines have been read
# 915 lines have been read
# 920 lines have been read
# 925 lines have been read
# 930 lines have been read
# 935 lines have been read
# 940 lines have been read
# 945 lines have been read
# 950 lines have been read
# 955 lines have been read
# 960 lines have been read
# 965 lines have been read
# 970 lines have been read
# 975 lines have been read
# 980 lines have been read
# 985 lines have been read
# 990 lines have been read
# 995 lines have been read
# 1000 lines have been read
# 1005 lines have been read
# 1010 lines have been read
# 1015 lines have been read
# 1020 lines have been read
# 1025 lines have been read
# 1030 lines have been read
# 1035 lines have been read
# 1040 lines have been read
# 1045 lines have been read
# 1050 lines have been read
# 1055 lines have been read
# 1060 lines have been read
# 1065 lines have been read
# 1070 lines have been read
# 1075 lines have been read
# 1080 lines have been read
# 1085 lines have been read
# 1090 lines have been read
# 1095 lines have been read
# 1100 lines have been read
# 1105 lines have been read
# 1110 lines have been read
# 1115 lines have been read
# 1120 lines have been read
# 1125 lines have been read
# 1130 lines have been read
# 1135 lines have been read
# 1140 lines have been read
# 1145 lines have been read
# 1150 lines have been read
# 1155 lines have been read
# 1160 lines have been read
# 1165 lines have been read
# 1170 lines have been read
# 1175 lines have been read
# 1180 lines have been read
# 1185 lines have been read
# 1190 lines have been read
# 1195 lines have been read
# 1200 lines have been read
# 1205 lines have been read
# 1210 lines have been read
# 1215 lines have been read
# 1220 lines have been read
# 1225 lines have been read
# 1230 lines have been read
# 1235 lines have been read
# 1240 lines have been read
# 1245 lines have been read
# 1250 lines have been read
# 1255 lines have been read
# 1260 lines have been read
# 1265 lines have been read
# 1270 lines have been read
# 1275 lines have been read
# 1280 lines have been read
# 1285 lines have been read
# 1290 lines have been read
# 1295 lines have been read
# 1300 lines have been read
# 1305 lines have been read
# 1310 lines have been read
# 1315 lines have been read
# 1320 lines have been read
# 1325 lines have been read
# 1330 lines have been read
# 1335 lines have been read
# 1340 lines have been read
# 1345 lines have been read
# 1350 lines have been read
# 1355 lines have been read
# 1360 lines have been read
# 1365 lines have been read
# 1370 lines have been read
# 1375 lines have been read
# 1380 lines have been read
# 1385 lines have been read
# 1390 lines have been read
# 1395 lines have been read
# 1400 lines have been read
# 1405 lines have been read
# 1410 lines have been read
# 1415 lines have been read
# 1420 lines have been read
# 1425 lines have been read
# 1430 lines have been read
# 1435 lines have been read
# 1440 lines have been read
# 1445 lines have been read
# 1450 lines have been read
# 1455 lines have been read
# 1460 lines have been read
# 1465 lines have been read
# 1470 lines have been read
# 1475 lines have been read
# 1480 lines have been read
# 1485 lines have been read
# 1490 lines have been read
# 1495 lines have been read
# 1500 lines have been read
# 1505 lines have been read
# 1510 lines have been read
# 1515 lines have been read
# 1520 lines have been read
# 1525 lines have been read
# 1530 lines have been read
# 1535 lines have been read
# 1540 lines have been read
# 1545 lines have been read
# 1550 lines have been read
# 1555 lines have been read
# 1560 lines have been read
# 1565 lines have been read
# 1570 lines have been read
# 1575 lines have been read
# 1580 lines have been read
# 1585 lines have been read
# 1590 lines have been read
# 1595 lines have been read
# 1600 lines have been read
# 1605 lines have been read
# 1610 lines have been read
# 1615 lines have been read
# 1620 lines have been read
# 1625 lines have been read
# 1630 lines have been read
# 1635 lines have been read
# 1640 lines have been read
# 1645 lines have been read
# 1650 lines have been read
# 1655 lines have been read
# 1660 lines have been read
# 1665 lines have been read
# 1670 lines have been read
# 1675 lines have been read
# 1680 lines have been read
# 1685 lines have been read
# 1690 lines have been read
# 1695 lines have been read
# 1700 lines have been read
# 1705 lines have been read
# 1710 lines have been read
# 1715 lines have been read
# 1720 lines have been read
# 1725 lines have been read
# 1730 lines have been read
# 1735 lines have been read
# 1740 lines have been read
# 1745 lines have been read
# 1750 lines have been read
# 1755 lines have been read
# 1760 lines have been read
# 1765 lines have been read
# 1770 lines have been read
# 1775 lines have been read
# 1780 lines have been read
# 1785 lines have been read
# 1790 lines have been read
# 1795 lines have been read
# 1800 lines have been read
# 1805 lines have been read
# 1810 lines have been read
# 1815 lines have been read
# 1820 lines have been read
# 1825 lines have been read
# 1830 lines have been read
# 1835 lines have been read
# 1840 lines have been read
# 1845 lines have been read
# 1850 lines have been read
# 1855 lines have been read
# 1860 lines have been read
# 1865 lines have been read
# 1870 lines have been read
# 1875 lines have been read
# 1880 lines have been read
# 1885 lines have been read
# 1890 lines have been read
# 1895 lines have been read
# 1900 lines have been read
# 1905 lines have been read
# 1910 lines have been read
# 1915 lines have been read
# 1920 lines have been read
# 1925 lines have been read
# 1930 lines have been read
# 1935 lines have been read
# 1940 lines have been read
# 1945 lines have been read
# 1950 lines have been read
# 1955 lines have been read
# 1960 lines have been read
# 1965 lines have been read
# 1970 lines have been read
# 1975 lines have been read
# 1980 lines have been read
# 1985 lines have been read
# 1990 lines have been read
# 1995 lines have been read
# 2000 lines have been read
# 2005 lines have been read
# 2010 lines have been read
# 2015 lines have been read
# 2020 lines have been read
# 2025 lines have been read
# 2030 lines have been read
# 2035 lines have been read
# 2040 lines have been read
# 2045 lines have been read
# 2050 lines have been read
# 2055 lines have been read
# 2060 lines have been read
# 2065 lines have been read
# 2070 lines have been read
# 2075 lines have been read
# 2080 lines have been read
# 2085 lines have been read
# 2090 lines have been read
# 2095 lines have been read
# 2100 lines have been read
# 2105 lines have been read
# 2110 lines have been read
# 2115 lines have been read
# 2120 lines have been read
# 2125 lines have been read
# 2130 lines have been read
# 2135 lines have been read
# 2140 lines have been read
# 2145 lines have been read
# 2150 lines have been read
# 2155 lines have been read
# 2160 lines have been read
# 2165 lines have been read
# 2170 lines have been read
# 2175 lines have been read
# 2180 lines have been read
# 2185 lines have been read
# 2190 lines have been read
# 2195 lines have been read
# 2200 lines have been read
# 2205 lines have been read
# 2210 lines have been read
# 2215 lines have been read
# 2220 lines have been read
# 2225 lines have been read
# 2230 lines have been read
# 2235 lines have been read
# 2240 lines have been read
# 2245 lines have been read
# 2250 lines have been read
# 2255 lines have been read
# 2260 lines have been read
# 2265 lines have been read
# 2270 lines have been read
# 2275 lines have been read
# 2280 lines have been read
# 2285 lines have been read
# 2290 lines have been read
# 2295 lines have been read
# 2300 lines have been read
# 2305 lines have been read
# 2310 lines have been read
# 2315 lines have been read
# 2320 lines have been read
# 2325 lines have been read
# 2330 lines have been read
# 2335 lines have been read
# 2340 lines have been read
# 2345 lines have been read
# 2350 lines have been read
# 2355 lines have been read
# 2360 lines have been read
# 2365 lines have been read
# 2370 lines have been read
# 2375 lines have been read
# 2380 lines have been read
# 2385 lines have been read
# 2390 lines have been read
# 2395 lines have been read
# 2400 lines have been read
# 2405 lines have been read
# 2410 lines have been read
# 2415 lines have been read
# 2420 lines have been read
# 2425 lines have been read
# 2430 lines have been read
# 2435 lines have been read
# 2440 lines have been read
# 2445 lines have been read
# 2450 lines have been read
# 2455 lines have been read
# 2460 lines have been read
# 2465 lines have been read
# 2470 lines have been read
# 2475 lines have been read
# 2480 lines have been read
# 2485 lines have been read
# 2490 lines have been read
# 2495 lines have been read
# 2500 lines have been read
# 2505 lines have been read
# 2510 lines have been read
# 2515 lines have been read
# 2520 lines have been read
# 2525 lines have been read
# 2530 lines have been read
# 2535 lines have been read
# 2540 lines have been read
# 2545 lines have been read
# 2550 lines have been read
# 2555 lines have been read
# 2560 lines have been read
# 2565 lines have been read
# 2570 lines have been read
# 2575 lines have been read
# 2580 lines have been read
# 2585 lines have been read
# 2590 lines have been read
# 2595 lines have been read
# 2600 lines have been read
# 2605 lines have been read
# 2610 lines have been read
# 2615 lines have been read
# 2620 lines have been read
# 2625 lines have been read
# 2630 lines have been read
# 2635 lines have been read
# 2640 lines have been read
# 2645 lines have been read
# 2650 lines have been read
# 2655 lines have been read
# 2660 lines have been read
# 2665 lines have been read
# 2670 lines have been read
# 2675 lines have been read
# 2680 lines have been read
# 2685 lines have been read
# 2690 lines have been read
# 2695 lines have been read
# 2700 lines have been read
# 2705 lines have been read
# 2710 lines have been read
# 2715 lines have been read
# 2720 lines have been read
# 2725 lines have been read
# 2730 lines have been read
# 2735 lines have been read
# 2740 lines have been read
# 2745 lines have been read
# 2750 lines have been read
# 2755 lines have been read
# 2760 lines have been read
# 2765 lines have been read
# 2770 lines have been read
# 2775 lines have been read
# 2780 lines have been read
# 2785 lines have been read
# 2790 lines have been read
# 2795 lines have been read
# 2800 lines have been read
# 2805 lines have been read
# 2810 lines have been read
# 2815 lines have been read
# 2820 lines have been read
# 2825 lines have been read
# 2830 lines have been read
# 2835 lines have been read
# 2840 lines have been read
# 2845 lines have been read
# 2850 lines have been read
# 2855 lines have been read
# 2860 lines have been read
# 2865 lines have been read
# 2870 lines have been read
# 2875 lines have been read
# 2880 lines have been read
# 2885 lines have been read
# 2890 lines have been read
# 2895 lines have been read
# 2900 lines have been read
# 2905 lines have been read
# 2910 lines have been read
# 2915 lines have been read
# 2920 lines have been read
# 2925 lines have been read
# 2930 lines have been read
# 2935 lines have been read
# 2940 lines have been read
# 2945 lines have been read
# 2950 lines have been read
# 2955 lines have been read
# 2960 lines have been read
# 2965 lines have been read
# 2970 lines have been read
# 2975 lines have been read
# 2980 lines have been read
# 2985 lines have been read
# 2990 lines have been read
# 2995 lines have been read
# 3000 lines have been read
# 3005 lines have been read
# 3010 lines have been read
# 3015 lines have been read
# 3020 lines have been read
# 3025 lines have been read
# 3030 lines have been read
# 3035 lines have been read
# 3040 lines have been read
# 3045 lines have been read
# 3050 lines have been read
# 3055 lines have been read
# 3060 lines have been read
# 3065 lines have been read
# 3070 lines have been read
# 3075 lines have been read
# 3080 lines have been read
# 3085 lines have been read
# 3090 lines have been read
# 3095 lines have been read
# 3100 lines have been read
# 3105 lines have been read
# 3110 lines have been read
# 3115 lines have been read
# 3120 lines have been read
# 3125 lines have been read
# 3130 lines have been read
# 3135 lines have been read
# 3140 lines have been read
# 3145 lines have been read
# 3150 lines have been read
# 3155 lines have been read
# 3160 lines have been read
# 3165 lines have been read
# 3170 lines have been read
# 3175 lines have been read
# 3180 lines have been read
# 3185 lines have been read
# 3190 lines have been read
# 3195 lines have been read
# 3200 lines have been read
# 3205 lines have been read
# 3210 lines have been read
# 3215 lines have been read
# 3220 lines have been read
# 3225 lines have been read
# 3230 lines have been read
# 3235 lines have been read
# 3240 lines have been read
# 3245 lines have been read
# 3250 lines have been read
# 3255 lines have been read
# 3260 lines have been read
# 3265 lines have been read
# 3270 lines have been read
# 3275 lines have been read
# 3280 lines have been read
# 3285 lines have been read
# 3290 lines have been read
# 3295 lines have been read
# 3300 lines have been read
# 3305 lines have been read
# 3310 lines have been read
# 3315 lines have been read
# 3320 lines have been read
# 3325 lines have been read
# 3330 lines have been read
# 3335 lines have been read
# 3340 lines have been read
# 3345 lines have been read
# 3350 lines have been read
# 3355 lines have been read
# 3360 lines have been read
# 3365 lines have been read
# 3370 lines have been read
# 3375 lines have been read
# 3380 lines have been read
# 3385 lines have been read
# 3390 lines have been read
# 3395 lines have been read
# 3400 lines have been read
# 3405 lines have been read
# 3410 lines have been read
# 3415 lines have been read
# 3420 lines have been read
# 3425 lines have been read
# 3430 lines have been read
# 3435 lines have been read
# 3440 lines have been read
# 3445 lines have been read
# 3450 lines have been read
# 3455 lines have been read
# 3460 lines have been read
# 3465 lines have been read
# 3470 lines have been read
# 3475 lines have been read
# 3480 lines have been read
# 3485 lines have been read
# 3490 lines have been read
# 3495 lines have been read
# 3500 lines have been read
# 3505 lines have been read
# 3510 lines have been read
# 3515 lines have been read
# 3520 lines have been read
# 3525 lines have been read
# 3530 lines have been read
# 3535 lines have been read
# 3540 lines have been read
# 3545 lines have been read
# 3550 lines have been read
# 3555 lines have been read
# 3560 lines have been read
# 3565 lines have been read
# 3570 lines have been read
# 3575 lines have been read
# 3580 lines have been read
# 3585 lines have been read
# 3590 lines have been read
# 3595 lines have been read
# 3600 lines have been read
# 3605 lines have been read
# 3610 lines have been read
# 3615 lines have been read
# 3620 lines have been read
# 3625 lines have been read
# 3630 lines have been read
# 3635 lines have been read
# 3640 lines have been read
# 3645 lines have been read
# 3650 lines have been read
# 3655 lines have been read
# 3660 lines have been read
# 3665 lines have been read
# 3670 lines have been read
# 3675 lines have been read
# 3680 lines have been read
# 3685 lines have been read
# 3690 lines have been read
# 3695 lines have been read
# 3700 lines have been read
# 3705 lines have been read
# 3710 lines have been read
# 3715 lines have been read
# 3720 lines have been read
# 3725 lines have been read
# 3730 lines have been read
# 3735 lines have been read
# 3740 lines have been read
# 3745 lines have been read
# 3750 lines have been read
# 3755 lines have been read
# 3760 lines have been read
# 3765 lines have been read
# 3770 lines have been read
# 3775 lines have been read
# 3780 lines have been read
# 3785 lines have been read
# 3790 lines have been read
# 3795 lines have been read
# 3800 lines have been read
# 3805 lines have been read
# 3810 lines have been read
# 3815 lines have been read
# 3820 lines have been read
# 3825 lines have been read
# 3830 lines have been read
# 3835 lines have been read
# 3840 lines have been read
# 3845 lines have been read
# 3850 lines have been read
# 3855 lines have been read
# 3860 lines have been read
# 3865 lines have been read
# 3870 lines have been read
# 3875 lines have been read
# 3880 lines have been read
# 3885 lines have been read
# 3890 lines have been read
# 3895 lines have been read
# 3900 lines have been read
# 3905 lines have been read
# 3910 lines have been read
# 3915 lines have been read
# 3920 lines have been read
# 3925 lines have been read
# 3930 lines have been read
# 3935 lines have been read
# 3940 lines have been read
# 3945 lines have been read
# 3950 lines have been read
# 3955 lines have been read

# %% [markdown]
# # Split dataset files to train, dev and test subfiles

# %%
def write_part(source, target, count):
    for i in xrange(count):
        target.write(source.readline())

def count_lines(path):
    with open(path, "r") as f:
        count = sum(1 for _ in f)
    return count

def create_dataset(source, target_path, postfix, dev_rat=0.14, test_rat=0.28):
    count = count_lines(source)
    with open(source, "r") as source_file:
        dev_count = int(count * dev_rat)
        test_count = int(count * test_rat)
        train_count = count - dev_count - test_count
        
        filename = "%s/sentiment.train.%s" % (target_path, postfix)
        with open(filename, "w") as f:
            write_part(source_file, f, train_count)
        
        filename = "%s/sentiment.dev.%s" % (target_path, postfix)
        with open(filename, "w") as f:
            write_part(source_file, f, dev_count)
        
        
        filename = "%s/sentiment.test.%s" % (target_path, postfix)
        with open(filename, "w") as f:
            write_part(source_file, f, test_count)

# %%
FINAL_DATASET_PATH = "data/news2tales/"

create_dataset("data/news/news-sents.txt", FINAL_DATASET_PATH, "0")
create_dataset("data/tales/tales-sents-full.txt", FINAL_DATASET_PATH, "1")

# %%
FINAL_DATASET_PATH = "data/news2dostoevsky/"

create_dataset("data/dostoevsky/dostoevsky-sents.txt", FINAL_DATASET_PATH, "1")
create_dataset("data/news/news-sents.txt", FINAL_DATASET_PATH, "0")

# %%
FINAL_DATASET_PATH = "data/marinina2dostoevsky/"

create_dataset("data/marinina/marinina-sents.txt", FINAL_DATASET_PATH, "0")
create_dataset("data/dostoevsky/dostoevsky-sents.txt", FINAL_DATASET_PATH, "1")

# %%
FINAL_DATASET_PATH = "data/marinina2tales/"

create_dataset("data/marinina/marinina-sents.txt", FINAL_DATASET_PATH, "0")
create_dataset("data/tales/tales-sents-full.txt", FINAL_DATASET_PATH, "1")
